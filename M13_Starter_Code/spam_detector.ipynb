# %% [markdown]
# # Spam Detector

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
# %matplotlib inline
from matplotlib import pyplot as plt
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Retrieve the Data
#
# The data is located at [https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv](https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv)
#
# Dataset Source: [UCI Machine Learning Library](https://archive.ics.uci.edu/dataset/94/spambase)
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %% [markdown]
# ## Predict Model Performance
#
# You will be creating and comparing two models on this data: a Logistic Regression, and a Random Forests Classifier. Before you create, fit, and score the models, make a prediction as to which model you think will perform better. You do not need to be correct!
#
# Write down your prediction in the designated cells in your Jupyter Notebook, and provide justification for your educated guess.

# %% [markdown]
# Answer: Random Forest, I think since it works better nonlinearly.

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Create the labels set `y` and features DataFrame `X`
X = data.copy()
X = X.drop(columns='spam')

y = data['spam']
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4596    0
# 4597    0
# 4598    0
# 4599    0
# 4600    0
# Name: spam, Length: 4601, dtype: int64

# %%
# Check the balance of the labels variable (`y`) by using the `value_counts` function.
y_balance = y.value_counts()
y_balance
# Out:
# spam
# 0    2788
# 1    1813
# Name: count, dtype: int64

# %%
# Split the data into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ## Scale the Features

# %% [markdown]
# Use the `StandardScaler` to scale the features data. Remember that only `X_train` and `X_test` DataFrames should be scaled.

# %%
from sklearn.preprocessing import StandardScaler

# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
# Scale the training data
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_train_scaled
# Out:
# array([[-0.34085316, -0.16705515, -0.55783684, ..., -0.10448542,
#          0.03134832, -0.1254257 ],
#        [-0.34085316, -0.16705515,  0.88561542, ..., -0.06870291,
#         -0.11063275, -0.24954485],
#        [-0.34085316, -0.16705515, -0.55783684, ..., -0.11339754,
#         -0.22421762, -0.42708237],
#        ...,
#        [-0.34085316, -0.16705515, -0.55783684, ..., -0.11500574,
#         -0.23368302, -0.43022463],
#        [-0.34085316, -0.16705515,  2.62566746, ..., -0.11500574,
#         -0.22895032, -0.41451335],
#        [-0.34085316, -0.16705515,  0.47037573, ..., -0.08987757,
#         -0.16269248, -0.26368501]])

# %%
X_test_scaled = scaler.transform(X_test)
X_test_scaled
# Out:
# array([[-0.34085316, -0.16705515, -0.55783684, ..., -0.08997809,
#         -0.17689059, -0.33595692],
#        [-0.34085316, -0.16705515, -0.10305051, ..., -0.09637739,
#         -0.13902897,  0.30820578],
#        [ 1.51672555, -0.16705515, -0.55783684, ..., -0.05898668,
#          0.33424129, -0.12071231],
#        ...,
#        [-0.34085316, -0.16705515, -0.55783684, ...,  0.18740338,
#          0.05974454, -0.22754905],
#        [-0.34085316, -0.16705515, -0.55783684, ..., -0.08706322,
#         -0.09170194, -0.24954485],
#        [-0.34085316, -0.16705515, -0.55783684, ..., -0.09610936,
#         -0.21001951, -0.40037319]])

# %% [markdown]
# ## Create and Fit a Logistic Regression Model
#
# Create a Logistic Regression model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Logistic Regression model and print the model score
from sklearn.linear_model import LogisticRegression
logistic_regression_model = LogisticRegression(random_state=1)

# %%
logistic_regression_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
print(f"Training Data Score: {logistic_regression_model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {logistic_regression_model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.9252173913043479
# Testing Data Score: 0.9313640312771503

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
testing_predictions = logistic_regression_model.predict(X_test_scaled)
# Review the predictions
print(testing_predictions)
# Out:
# [0 0 1 ... 1 0 0]

# %%
from joblib import dump
dump(logistic_regression_model, 'logistic_regression_model')
# Out:
# ['logistic_regression_model']

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
from sklearn.metrics import accuracy_score
print(f" Accuracy Score: {accuracy_score(y_test, testing_predictions)}")
# Out:
#  Accuracy Score: 0.9313640312771503

# %% [markdown]
# ## Create and Fit a Random Forest Classifier Model
#
# Create a Random Forest Classifier model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Import the data
data2 = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
data2.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %%
# Train a Random Forest Classifier model and print the model score
X = data2.drop(columns='spam')
y = data2['spam']
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4596    0
# 4597    0
# 4598    0
# 4599    0
# 4600    0
# Name: spam, Length: 4601, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Fit the Standard Scaler with the training data
# Scale the training data
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_train_scaled
# Out:
# array([[-0.33933373, -0.16214839, -0.55144324, ..., -0.11649103,
#         -0.21175305, -0.41909144],
#        [ 1.8777157 , -0.16214839, -0.55144324, ..., -0.10814021,
#         -0.18841316, -0.35960578],
#        [-0.33933373, -0.16214839,  2.2325961 , ...,  0.21993678,
#          0.29705664, -0.10941609],
#        ...,
#        [-0.33933373, -0.16214839, -0.55144324, ..., -0.08642808,
#         -0.20241709, -0.40334524],
#        [-0.33933373,  0.02143809, -0.55144324, ..., -0.10902256,
#         -0.18841316, -0.18639753],
#        [-0.00843083, -0.16214839,  0.25239911, ..., -0.09960031,
#         -0.1137255 ,  0.10403246]])

# %%
X_test_scaled = scaler.transform(X_test)
X_test_scaled
# Out:
# array([[-0.33933373, -0.16214839, -0.55144324, ..., -0.12843428,
#         -0.2444289 , -0.48382584],
#        [ 2.01007686, -0.16214839,  0.84057643, ..., -0.12742588,
#         -0.23976092, -0.43308807],
#        [-0.33933373, -0.16214839,  1.23269465, ..., -0.11835027,
#         -0.21642103, -0.30886801],
#        ...,
#        [-0.1077017 ,  0.01345607,  1.05624145, ..., -0.05189034,
#          0.09633355,  1.21501465],
#        [-0.33933373, -0.16214839, -0.55144324, ..., -0.10952676,
#         -0.23042497, -0.47507794],
#        [-0.33933373, -0.16214839, -0.23774866, ..., -0.07788818,
#         -0.11839347,  0.83710575]])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(n_estimators=128, random_state=78)

# %%
# Train the Random Forest model
rf_model = rf_model.fit(X_train_scaled, y_train)
rf_model
# Out:
# RandomForestClassifier(n_estimators=128, random_state=78)

# %%
# Evaluate the model
print(f'Training Score: {rf_model.score(X_train_scaled, y_train)}')
print(f'Testing Score: {rf_model.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 0.9994202898550725
# Testing Score: 0.9582971329278888

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
testing_predictions_rf = rf_model.predict(X_test_scaled)

# Review the predictions
testing_predictions_rf
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
from joblib import dump
dump(rf_model, 'rf_model')
# Out:
# ['rf_model']

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
print(f" Accuracy Score: {accuracy_score(y_test, testing_predictions_rf)}")
# Out:
#  Accuracy Score: 0.9582971329278888

# %% [markdown]
# ## Evaluate the Models
#
# Which model performed better? How does that compare to your prediction? Write down your results and thoughts in the following markdown cell.

# %% [markdown]
# Random Forest performed marginally better, confirming my initial hypothesis. Random Forest is more robust as it can handle the importance of different features and model non-linearity which is assumed of spam detection. The Logistic Regression model still performed amazingly well and can be used to preserve computation power without sacrificing speed in the future.
